# %%
# key:-2bddfe57fb7677f06780a8fd3ffe5e94

# %%
import requests
import json
header={"User-Agent":"Subh","Accept":"application/json","user-key":"2bddfe57fb7677f06780a8fd3ffe5e94"}
a=requests.get('https://developers.zomato.com/api/v2.1/cities?',params={'q':'Mexico'},headers=header)
b=a.json()
b
# Out:
# {'location_suggestions': [{'id': 6120,
#    'name': 'Mexico, ME',
#    'country_id': 216,
#    'country_name': 'United States',
#    'country_flag_url': 'https://b.zmtcdn.com/images/countries/flags/country_216.png',
#    'should_experiment_with': 0,
#    'has_go_out_tab': 0,
#    'discovery_enabled': 0,
#    'has_new_ad_format': 0,
#    'is_state': 0,
#    'state_id': 89,
#    'state_name': 'Maine',
#    'state_code': 'ME'},
#   {'id': 964,
#    'name': 'Albuquerque, NM',
#    'country_id': 216,
#    'country_name': 'United States',
#    'country_flag_url': 'https://b.zmtcdn.com/images/countries/flags/country_216.png',
#    'should_experiment_with': 0,
#    'has_go_out_tab': 0,
#    'discovery_enabled': 0,
#    'has_new_ad_format': 0,
#    'is_state': 0,
#    'state_id': 101,
#    'state_name': 'New Mexico',
#    'state_code': 'NM'},
#   {'id': 970,
#    'name': 'Santa Fe, NM',
#    'country_id': 216,
#    'country_name': 'United States',
# ...

# %%
import requests
import json
header={"User-Agent":"Subh","Accept":"application/json","user-key":"2bddfe57fb7677f06780a8fd3ffe5e94"}
a=requests.get('https://developers.zomato.com/api/v2.1/cuisines',params={'city_id':964},headers=header)
b=a.json()
b
for i in b['cuisines']:
    if i['cuisine']['cuisine_name']=='Mexican':
        print(i['cuisine']['cuisine_id'])
# Out:
# 73

# %%
import requests
import json
header={"User-Agent":"Subh","Accept":"application/json","user-key":"2bddfe57fb7677f06780a8fd3ffe5e94"}
a=requests.get('https://developers.zomato.com/api/v2.1/locations',params={'query':'Connaught Place'},headers=header)
b=a.json()
ans=b['location_suggestions'][0]
print(ans['entity_type'],ans['entity_id'])
# Out:
# subzone 104

# %%
import requests
import json
header={"User-Agent":"Subh","Accept":"application/json","user-key":"2bddfe57fb7677f06780a8fd3ffe5e94"}
a=requests.get('https://developers.zomato.com/api/v2.1/search',params={'entity_type':'subzone','entity_id':'104','sort':'rating'},headers=header)
b=a.json()
ans=b['restaurants']
print(len(ans))
for i in range(len(ans)):
    d=ans[i]
    p=d['restaurant']['cuisines'].split(',')
    l=[]
    for name in p:
        if name!= '':
            l.append(name.strip())
    print(l)
# Out:
# 20
# ['Mexican', 'American', 'Italian']
# ['Finger Food', 'North Indian', 'Italian', 'Chinese', 'Continental']
# ['North Indian', 'Mughlai']
# ['Italian', 'North Indian', 'Mughlai', 'Modern Indian']
# ['Continental', 'Italian', 'Asian', 'Momos']
# ['Portuguese', 'Wraps', 'Burger', 'Salad']
# ['Ice Cream']
# ['Bakery', 'Fast Food', 'Desserts']
# ['Cafe', 'Fast Food', 'Beverages']
# ['Cafe']
# ['Paan']
# ['Chinese', 'Continental', 'North Indian', 'Asian', 'Kebab', 'Beverages']
# ['South Indian', 'North Indian', 'Beverages']
# ['Malaysian', 'Thai', 'Kerala', 'Vietnamese', 'Sri Lankan']
# ['Bakery', 'Cafe', 'Fast Food', 'Desserts', 'Beverages']
# ['South Indian', 'Mithai', 'Beverages']
# ['Modern Indian']
# ['North Indian', 'Chinese', 'BBQ']
# ['Fast Food', 'Desserts', 'Beverages']
# ['Cafe', 'Desserts']

# %%
import requests
import json
header={"User-Agent":"Subh","Accept":"application/json","user-key":"2bddfe57fb7677f06780a8fd3ffe5e94"}
a=requests.get('https://developers.zomato.com/api/v2.1/location_details',params={'entity_type':'subzone','entity_id':'104'},headers=header)
b=a.json()
ans=b['best_rated_restaurant']
print(len(ans))
for i in range(len(ans)):
    d=ans[i]
    p=d['restaurant']['cuisines'].split(',')
    l=[]
    for name in p:
        if name!= '':
            l.append(name.strip())
    print(l)
# Out:
# 10
# ['Mithai', 'North Indian', 'Street Food', 'South Indian', 'Bakery', 'Chinese', 'Fast Food']
# ['North Indian', 'Chinese', 'Continental', 'Italian']
# ['Cafe', 'Fast Food', 'Beverages']
# ['South Indian', 'Mithai', 'Beverages']
# ['Ice Cream']
# ['Cafe', 'Desserts']
# ['North Indian', 'Chinese', 'BBQ']
# ['Portuguese', 'Wraps', 'Burger', 'Salad']
# ['Bakery', 'Fast Food', 'Desserts']
# ['Modern Indian']

# %%
import requests
import json
header={"User-Agent":"Subh","Accept":"application/json","user-key":"2bddfe57fb7677f06780a8fd3ffe5e94"}
a=requests.get('https://developers.zomato.com/api/v2.1/categories',params={'q':'Mexico'},headers=header)
b=a.json()

ans=b['categories']
for i in range(len(ans)):
    if ans[i]['categories']['name']=='Cafes':
        print(ans[i]['categories']['id'])
# Out:
# 6

# %%
import requests
import json
header={"User-Agent":"Subh","Accept":"application/json","user-key":"2bddfe57fb7677f06780a8fd3ffe5e94"}
a=requests.get('https://developers.zomato.com/api/v2.1/search',params={'entity_type':'subzone','entity_id':'104','sort':'rating','cuisines':[73],'category':'Cafes'},headers=header)
b=a.json()
b
# Out:
# {'results_found': 38,
#  'results_start': 0,
#  'results_shown': 20,
#  'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1,
#       'takeaway': -1},
#      'res_id': 18537536},
#     'apikey': '2bddfe57fb7677f06780a8fd3ffe5e94',
#     'id': '18537536',
#     'name': "Chili's Grill & Bar",
#     'url': 'https://www.zomato.com/ncr/chilis-grill-bar-connaught-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'M-9, Outer Circle, Connaught Place, New Delhi',
#      'locality': 'Connaught Place',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6314993603',
#      'longitude': '77.2222650424',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Connaught Place, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Mexican, American, Italian',
#     'timings': '12 Noon to 1 AM',
#     'average_cost_for_two': 1200,
#     'price_range': 3,
# ...

# %%
## Open and read data file as specified in the question
## Print the required output in given format
import requests
import json
header={"User-Agent":"Subh","Accept":"application/json","user-key":"2bddfe57fb7677f06780a8fd3ffe5e94"}
a=requests.get('https://developers.zomato.com/api/v2.1/reviews',params={'res_id':18729557},headers=header)
b=a.json()
r=b['user_reviews']
r
for i in range(len(r)):
    d=r[i]['review']
    print(d['user']['name'],d['rating'],d['review_text'])
# Out:
# Ayush Bhagat 5
# Hina Vohra 4
# Shivansh 4
# Temptingtastebuds__ 5 This outlet of xero degrees in connaught place, One of my most recommended place . Pocket friendly,comfortable seating area and polite staff. They serve food on time. Totally clean and hygienic place. I ordered here jar pizza and it is filled with cheese and I just loved it. Must hit this place with your friends.
# Saurabh Banderwal 5 10 months ago  Hidden gem in Connaught place... pocket friendly....good food n mocktails....

# %%
import requests
import json
header={"User-Agent":"Subh","Accept":"application/json","user-key":"2bddfe57fb7677f06780a8fd3ffe5e94"}
a=requests.get('https://developers.zomato.com/api/v2.1/restaurant',params={'res_id':18241524},headers=header)
b=a.json()
print(b['user_rating']['aggregate_rating'])
print(b['average_cost_for_two'])
print(b['cuisines'])
print(b['location']['address'])
# Out:
# 4.2
# 1400
# North Indian, Continental, Italian, Chinese
# G-15/B, Vijay Nagar, New Delhi

# %%
if b['has_online_delivery']==0:
    print('no')
else:
    print('yes')
# Out:
# 0

# %%
import requests
import json
header={"User-Agent":"Subh","Accept":"application/json","user-key":"2bddfe57fb7677f06780a8fd3ffe5e94"}
a=requests.get('https://developers.zomato.com/api/v2.1/cuisines',params={'lat':28.69787,'lon':77.140595},headers=header)
b=a.json()['cuisines']
for i in range(len(b)):
    ans=b[i]['cuisine']
    if ans['cuisine_name']=='BBQ':
        print(ans['cuisine_id'])
# Out:
# 193

# %%
import requests
import json
header={"User-Agent":"Subh","Accept":"application/json","user-key":"2bddfe57fb7677f06780a8fd3ffe5e94"}
a=requests.get('https://developers.zomato.com/api/v2.1/search',params={'entity_type':'subzone','entity_id':282,'sort':'rating','cuisines':[193],'radius':1},headers=header)
b=a.json()

ans=b['restaurants']
count=0
for i in range(len(ans)):
    d=ans[i]
    if count<10:

            print(d['restaurant']['name'],d['restaurant']['user_rating']['aggregate_rating'],d['restaurant']['id'],d['restaurant']['location']['locality'])
    count+=1
# Out:
# Themis Barbecue House 4.5 18204820 Netaji Subhash Place
# New Bombay Bar-Be-Que 3.6 5303 Prashant Vihar

# %%
ans
# Out:
# [{'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#     'res_id': 18317477},
#    'apikey': '2bddfe57fb7677f06780a8fd3ffe5e94',
#    'id': '18317477',
#    'name': 'The Barbeque Company',
#    'url': 'https://www.zomato.com/ncr/the-barbeque-company-karkardooma-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'location': {'address': '4, Hargovind Enclave, Opposite Shanti Mukund Hospital, Karkardooma, New Delhi',
#     'locality': 'Karkardooma',
#     'city': 'New Delhi',
#     'city_id': 1,
#     'latitude': '28.6461757659',
#     'longitude': '77.3010100052',
#     'zipcode': '110092',
#     'country_id': 1,
#     'locality_verbose': 'Karkardooma, New Delhi'},
#    'switch_to_order_menu': 0,
#    'cuisines': 'North Indian, Chinese, Continental, BBQ',
#    'timings': '12 Noon to 3 PM, 6:30 PM to 11 PM (Mon-Fri), 12 Noon to 3:30 PM, 6:30 PM to 11 PM (Sat-Sun)',
#    'average_cost_for_two': 1300,
#    'price_range': 3,
# ...

# %%
## Open and read data file as specified in the question
## Print the required output in given format
## Open and read data file as specified in the question
## Print the required output in given format
import requests
import json
header={"User-Agent":"Subh","Accept":"application/json","user-key":"2bddfe57fb7677f06780a8fd3ffe5e94"}
a=requests.get('https://developers.zomato.com/api/v2.1/search',params={'lat':28.6975,'lon':77.1406,'sort':'rating','order':'desc','radius':4000 },headers=header)
b=a.json()

ans=b['restaurants']
count=0
for i in range(len(ans)):
    d=ans[i]
    if count<10:

            print(d['restaurant']['name'],d['restaurant']['user_rating']['aggregate_rating'],d['restaurant']['id'],d['restaurant']['location']['locality'])
    count+=1
# Out:
# Oishii Wok 4.9 19078918 DLF Phase 4
# Indian Accent 4.9 2004 The Lodhi, Lodhi Road
# Dana Choga 4.9 549 Sector 14
# Son Of A Bun 4.9 19300210 Golf Course Road
# Chili's Grill & Bar 4.9 18607069 Pacific Mall, Tagore Garden
# The Tandoori Tales 4.9 19231934 Sector 45
# Shanghai Surprise 4.9 19139037 DLF Phase 3
# Ah So Yum 4.8 18945610 Golf Course Road
# Master Koii's 4.8 18819947 Sushant Lok
# Chili's Grill & Bar 4.8 4751 Ambience Mall, Vasant Kunj
